# %%
from stormvogel import *
mdp = examples.monty_hall.create_monty_hall_mdp()
vis = show(mdp, show_editor=True)
# [26: 1/6, 28: 1/6, 33: 1/3, 41: 1/3, ] <= 9/10; 
# [13: 1/6, 14: 1/6, 17: 1/3, 21: 1/3, ] <= 9/10; 
# [4: 1/3, 7: 1/3, 10: 1/3, ] <= 9/10; 
# [1: 1/3, 2: 1/3, 3: 1/3, ] <= 9/10; 
# [0: 1, ] <= 9/10; 
# }
# Out:
# Output()
# ...
