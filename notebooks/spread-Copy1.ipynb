# %%
import stormvogel as sv
import networkx as nx
import stormpy
path = "../benchmarks/zero_conf_small.pm"

def lyt(graph):
    return nx.bfs_layout(graph, 0)

prism_propgram = stormpy.parse_prism_program(path)
model = sv.stormpy_utils.from_prism(prism_propgram)
sv.show(model, show_editor=True)
# Out:
# Output()
# HBox(children=(Output(), Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': 'Output()', 'a…
