# %%
import islpy as isl

F = isl.PwAff("{ [x, y] -> [(1)] : 0 <= x <= 5 and y >= 0 and -x < y <= 2; [x, y] -> [(2)/5] : x = 0 and y = 0 }")
p = F.eval(isl.Point(" { [1,1] } ")
# Out:
#   Cell In[5], line 4
#     p = F.eval(isl.Point(" { [1,1] } ")
#                                        ^
# SyntaxError: incomplete input
