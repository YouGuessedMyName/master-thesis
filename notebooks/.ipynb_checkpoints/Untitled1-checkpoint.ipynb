# %%
import islpy as isl
ctx = isl.DEFAULT_CONTEXT
f = isl.PwAff.read_from_str(
    ctx,
    "{ [x] -> 0 : x mod 2 = 1; "
    "  [x] -> 1 : x mod 2 = 0 }"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import islpy as isl
#       2 f = isl.PwAff.read_from_str(
# ----> 3     ctx,
#       4     "{ [x] -> 0 : x mod 2 = 1; "
#       5     "  [x] -> 1 : x mod 2 = 0 }"
#       6 )
#
# NameError: name 'ctx' is not defined
