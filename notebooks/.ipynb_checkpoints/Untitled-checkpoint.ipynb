# %%
import islpy as isl

# %%
F_poly = isl.PwQPolynomial("{ [x] -> x : 0 <= x <= 1; }")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 F_poly = isl.PwQPolynomial("{ [x] -> x+y : 0 <= x <= 1; }")
#
# Error: call to isl_pw_qpolynomial_read_from_str failed: syntax error in isl_stream.c:149

# %%
F_poly.sum()
# Out:
# PwQPolynomial("{ NaN }")
